# %% [markdown]
# # Sentence Splitter
# Simple script to split paragraphs of sentences into individual sentences

# %%
import pandas as pd
import os
import re
from transformers import pipeline

# %%
cwd = os.path.abspath(os.getcwd())
os.chdir(cwd)  # changes cwd to script's directory
data_dirname = "data"
data_dir = os.path.join(cwd, data_dirname)
# create data directory if it doesn't exist
if not os.path.exists(data_dir):
    os.makedirs(data_dir)
input_filename = "processed_stories.txt"
processed_stories_path = os.path.join(data_dir, input_filename)
with open(processed_stories_path, "r", encoding="utf-8") as f:
    text = f.read()
    start_match = re.search(r"dedicatoria", text, flags=re.IGNORECASE)
    end_match = re.search(r"índice", text, flags=re.IGNORECASE)
    if start_match and end_match:
        text = text[start_match.end():end_match.start()]
    
    text = text.replace("-\n", "")   # remove word splits across lines
    text = text.replace("\n", " ")   # replace newlines with spaces

    sentences = text.lower().strip().split(". ")  # simple sentence splitting by period followed by space

print(sentences)  # Display the first few sentences
# Out:
# ['muy especialmente a mi originario pueblo warao; a las comunidades indígenas de jobure de guayo, araguaimujo, musimurina, pascuala, españa, murako y guayaboroina de guayo, del municipio antonio díaz', 'así mismo, winamorena ii, pedernales, culebrita, del municipio pedernales, estado delta amacuro', '…que sigamos cosechando éxitos para nuestro pueblo', 'a ka nobo (dios) por todo lo que me ha dado', 'a mi mamá, carmen felisa bastardo, a mi papá eleuterio medrano, hermanos y sobrinos', 'a los niños, niñas y adolescentes warao y jotarao del delta amacuro', '   karata warao sebe obonobune isia nonae warao tuma ebe yatamo kuana yaotae kuare, saba nonae', 'ama janokosebe arao tuma, jobure de guayo, araguaimujo, musimurina, pascuala, españa, murako guayaboroina de guayo del municipio antonio díaz ama rakate, winamorena ii, pedernales, culebrita, municipio pederales, tane', '…nome ka cultura ama ka jobaji isia yakeraja yaotaki ama nobotomo tuma warao ama jotarao ka jobaji delta amacuro eku k
# ...

# %%
pipe = pipeline("text-classification", model="papluca/xlm-roberta-base-language-detection")
# Out:
# Invalid URL '/api/resolve-cache/models/papluca/xlm-roberta-base-language-detection/9865598389ca9d95637462f743f683b51d75b87b/config.json?%2Fpapluca%2Fxlm-roberta-base-language-detection%2Fresolve%2Fmain%2Fconfig.json=&etag=%22c99fbb09b11673f64aa2f6f1541eddae009e9383%22': No scheme supplied. Perhaps you meant https:///api/resolve-cache/models/papluca/xlm-roberta-base-language-detection/9865598389ca9d95637462f743f683b51d75b87b/config.json?%2Fpapluca%2Fxlm-roberta-base-language-detection%2Fresolve%2Fmain%2Fconfig.json=&etag=%22c99fbb09b11673f64aa2f6f1541eddae009e9383%22?
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# File c:\Users\anaco\miniconda3\envs\cs230-warao\lib\site-packages\transformers\configuration_utils.py:550, in PretrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     548 try:
#     549     # Load from URL or cache if already cached
# ...

# %%
warao_sentences = []
spanish_sentences = []
for s in sentences:
    lang = pipe(s)[0]['label']
    if lang == "es":
        spanish_sentences.append(s)
    else: 
        warao_sentences.append(s)

print(f"Spanish sentences: {spanish_sentences} \n Warao sentences: {warao_sentences}" )
df = pd.DataFrame({
    "warao_sentences": warao_sentences,
    "spanish_sentences": spanish_sentences
})
df.head(10)

# %%
df.to_csv(os.path.join(data_dir, "warao_spanish_stories_sentences.csv"), index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
ya waraotuma a erijawara naminakitane a ma areje tuma naminakitane nome uribaneitu nokokitane a janoko eku dujunae, yakaraja dibubui. Nome, warao tuma a de niabu isia oko kokotuka naminaya, nobotomo tuma jotarao tuma ama warao tuma dakate tai kuare awajabara. Yakaraja obonobukore, ribu kotai eraja jobaji emo dakate ja tai kuare, are bajete nobotomo a ku eku, ka kua eku, nobo ama natu isimo naminakitane ja, tamaja deniabu tuma, arai idajido tuma ayamo deniabu warabute, yakaraja nokokore ama naminakore dakate. Obonobukore, nome tane munuka Yordana Medra no, a musibu ja a cultura kotai a kobe eku ja, waraowitu a obonobu ja, a daunaida mija, ojiduina jakotai, a namina  abayaja, ama a rima tuma dakate aisimo naminaya tatuma warao tuma kuare, tamaja kasaba yakaera ine oriwakaya, tamaja karata a nona jido kuare, tai a jabata, warao tuna a deniabu, a nobo tuma a deniaabu, dibu mana a bane, warao ama jotarao tane teribumiaroi, takotare a sita tuma inarao tuma situbuae tai Rubisney Medrano jakotai, tane sike ka ribu, ama ine dibuya, tamaja karata mikore bare tuma isia obonobuya, tai bare Basilio Barral karata warao isia nonae dakate ama Fray Cesáreo de Armellada tai daka te karata dibu mana nonae, warao tuma jobaji emo ja kotai isia, Tauron Panton I ama Tauron Panton II, tamaja karata eku dibuya, warao tuma a ribu ama a reje, sé yaorokitane ja, takore warao tuma a ribu a jono isia dibukore a jono erijakore nome arawanera nome sanera dijana a mianare ekida,taisia naruya obonobunaka a jono ama a ribu tane muanaya. Ama Yordana Medrano, a nesenobo tuma ama ka nobo tuma, ka saba yabanae a jokonamu munuka, ama tai a raisa tuma ama jotarao tuma naminane tate a teribu isia, ama a jabata isia, tai munuka daisa jakore nome warao tuma, jotaro tuma naminane tate ama a reje tuma dakate eko tanaka tate. Tamaja karata kotai Warao tuma a Deniabu isia Waraya, yakaraja teribukore, ka obonona taisia naruya, ekey tia, nome sike yorikuare warakitane ama ka obonobu dakate emo naruya ka nese nobo ama ka nobo tuma yata abaya tamaisia wirinoko ekuya."

prologue_pars = [prologue_spanish, prologue_warao]

# %%
spanish_sentences = prologue_spanish.split(".")
warao_sentences = prologue_warao.split(".")

print(spanish_sentences, len(spanish_sentences))
print("number of spanish sentences: ", len(spanish_sentences))
print(warao_sentences, len(warao_sentences))
print("number of warao sentences: ", len(warao_sentences))
# Out:
# ['En el estado Delta Amacuro conocí a una joven warao con una dinámica y capacidad de trabajo envidiables en el mejor de los términos', ' Habla perfectamente su idioma, canta, cuenta y mantiene con profundo arraigo su cultura', ' Aunque vive en el Municipio Tucupita, capital del Estado donde se generan gran cantidad de impactos de transculturación, a ella no le causan sino fortalecimiento para mantener vivo sus orígenes', ' Confieso que rápidamente hicimos empatía; de allí llegó la oportunidad: el evento es en la ciudad de Caracas; “Palabras Ancestrales” denominó Francisco Sesto, Viceministro de Cultura para la época, aquella concentración de representantes de todos los grupos étnicos del país', ' Esto sirvió para presentar a Yordana Medrano en calidad de traductora warao de la señora Felisa Bastardo, su querida madre', ' Los asistentes al teatro Teresa Carreño ese día escucharon con atención aquellos cuentos que parecían tener vida en la voz de sus intérpretes, hija y nieta de wisid
# ...

# %%
df = pd.DataFrame({
                    "warao_sentences": warao_sentences,
                    "spanish_sentences": spanish_sentences[:len(warao_sentences)]
                    })

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.DataFrame({
#       2                     "warao_sentences": warao_sentences,
#       3                     "spanish_sentences": spanish_sentences
#       4                     })
#       6 df
#
# File c:\Users\anaco\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
# ...
