# %%
import pandas as pd

# %%
# load all sheets from drive
# sheet ID comes from URL
sheet_ids = [
            '1Pxs2JngjAQ_iqTtVuzy0xGcyPP7K7F-rumOiN3DcQJI', 
            '1Ktl2TXZPVme2NgTTt-_MivE7X-sTRnrZYHNj6LTzb9I', 
            '1y5Zuh-v-LyRmxurUzpgcfHHdh2eiybRgGiD5K6bYLT8', 
            '1teYR0T8bsXBTTcb1cf00UNFXDgXzmOCh-W2dl7I_fFY'
            ] 
sheet_names = [
                'Curso_Basico_Sentence_Pairs', 
                'PS_jw_website', 
                'Warao-Aribu-Learning-Guide-Data',
                'Trab_Warao_Completo'
                ]

df_lst = [pd.DataFrame(), pd.DataFrame(), pd.DataFrame(), pd.DataFrame()]

for i in range(len(sheet_ids)):
    sheet_id = sheet_ids[i]
    sheet_name = sheet_names[i]
    url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

    df_lst[i] = pd.read_csv(url)

# %%
df_curso_basico, df_ps_jw_website, df_warao_aribu_guide, df_trab_warao_completo = df_lst[0], df_lst[1], df_lst[2], df_lst[3]

# %% [markdown]
# ## Display Data

# %%
print(f"Number of examples from {sheet_names[0]}: {df_curso_basico.shape[0]}")
display(df_curso_basico.head(10))
# Out:
# Number of examples from Curso_Basico_Sentence_Pairs: 583
#              warao_sentence           spanish_sentence_1  \
# 0          ¿Waraotuma sina?      ¿Quienes son los warao?
# 1              Ka ribu isía  Sobre nuestro idioma warao.
# 2     Ine buratana najoroya               Yo como cambur
# 3     Iji buratana najoroya              Tú comes cambur
# 4     Tai buratana najoroya             Ella come cambur
# 5     Oko Buratana najoroya      Nosotros comemos cambur
# 6    Yatu buratana najoroya         Ustedes comen cambur
# 7  Tatuma buratana najoroya           Ellos comen cambur
# 8       Ine karata teribuya                   Yo estudio
# 9     Ine Jomakaba najoroya              Yo como pescado
#
#         spanish_sentence_2 spanish_sentence_3 spanish_sentence_4
# 0                      NaN                NaN                NaN
# 1                      NaN                NaN                NaN
# 2                      NaN                NaN                NaN
# 3                      NaN                NaN                NaN
# 4           Él come cambur                NaN                NaN
# 5  Nosotras comemos cambur                NaN                NaN
# 6                      NaN                NaN                NaN
# 7       ellas comen cambur                NaN                NaN
# 8                      NaN                NaN                NaN
# 9                      NaN                NaN                NaN

# %%
print(f"Number of examples from {sheet_names[1]}: {df_ps_jw_website.shape[0]}")
display(df_ps_jw_website.head(10))
# Out:
# Number of examples from PS_jw_website: 50
#                                       warao_sentence  \
# 0                     BIBLIA ISIA INAMINAKITANE SABA
# 1                              Iji oriwakane ubakuna
# 2  Iji Biblia isia naminakore tamaja denokotuma i...
# 3                     Katukane ine oriwakane jakuna?
# 4       Ya jisaka eku orikuba sanamata tane ekorate?
# 5         Maoriwarao muanaubuae jakutai atae mitera?
# 6                            Dio maisia obonobuyara?
# 7  Katukane ine Dio isiko dibakitane ja, tai mari...
# 8                     Naminau katukane oko inaminaya
# 9                        Inamina kokotuka amoara omi
#
#                                     spanish_sentence
# 0       PROGRAMA DE CLASES PARTICULARES DE LA BIBLIA
# 1                                                NaN
# 2  En este curso interactivo de la Biblia descubr...
# 3                  ¿Cómo puedo tener una vida feliz?
# 4  ¿Se acabarán algún día la maldad y el sufrimie...
# 5  ¿Volveré a ver a mis seres queridos que han mu...
# 6                          ¿Se preocupa Dios por mí?
# 7  ¿Cómo tengo que orarle a Dios para que me escu...
# 8                              Conozca nuestro curso
# 9                       El curso completo es gratis.

# %%
print(f"Number of examples from {sheet_names[2]}: {df_warao_aribu_guide.shape[0]}")
display(df_warao_aribu_guide.head(10))
# Out:
# Number of examples from Warao-Aribu-Learning-Guide-Data: 203
#                                       warao_sentence  \
# 0                                    Ka Nonatu saba.
# 1              Ka rima tuma ama ka rani tuma rakate.
# 2         Nobotomo Delta Amacuro arao kokotuka saba.
# 3  Nobotomo ainaminamo tuma saba rakate tamaja ka...
# 4                 Waraotuma ka sanetamo saba rakate.
# 5                                    Warao tuma yori
# 6                                      ¡kuare asaya!
# 7                                       aidamo aribu
# 8                                      nome nokobuae
# 9                                    ¡mojoju tanaka!
#
#                                     spanish_sentence
# 0                           A Dios, nuestro creador.
# 1                                 A nuestros padres.
# 2  A los niños Warao de todas las Comunidades Ind...
# 3  Al personal Docente que labora en las diversas...
# 4  A todas aquellas personas que nos ayudaron en ...
# 5                             Gloria al bravo pueblo
# 6                                  Que el yugo lanzó
# 7                                  La ley respetando
# 8                                  La virtud y honor
# 9                                    ¡Abajo cadenas!

# %%
print(f"Number of examples from {sheet_names[3]}: {df_trab_warao_completo.shape[0]}")
display(df_trab_warao_completo.head(10))
# Out:
# Number of examples from Trab_Warao_Completo: 129
#                                       warao_sentence  \
# 0  Tamaja karata ine dioso saba jabatae. Tai naru...
# 1  Ma rima, Dani , daka Tuma, dajia Tuma Marisa k...
# 2  Ma inaminatuyakera ma isiko, ma nokoae sina in...
# 3  Yakera masaba ma inaminanoko. Ma saba moae yak...
# 4      Ma inamena yakeraja ma konaruae inaminakitane
# 5     Yakeraja m asaba warao kokotuka ma isiko tanae
# 6  Inaminakitane eku kabiate nunae tae nunakitane...
# 7                                         ¿Katukete?
# 8                                      Bajuka sabuka
# 9                                  Yakera yana asida
#
#                                     spanish_sentence Unnamed: 2  Unnamed: 3  \
# 0  Dedico esta guía a Dios todo poderoso por darm...        NaN         NaN
# 1  A mis padres, hermanos, mis amigos por enseñar...        NaN         NaN
# 2  A mi profesor por la paciencia sostenida duran...        NaN         NaN
# 3  Agradezco a la universidad bolivariana de Vene...        NaN         NaN
# 4  A mi profesor por llevarnos por el camino corr...        NaN         NaN
# 5  A todas aquellas personas que me brindaron su ...        NaN         NaN
# 6  Crear cambios en las educaciones es una obliga...        NaN         NaN
# 7                                       ¿Cómo estás?        NaN         NaN
# 8                                            Regular        NaN         NaN
# 9                                          Estoy mal        NaN         NaN
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
# 5         NaN         NaN         NaN         NaN         NaN         NaN
# 6         NaN         NaN         NaN         NaN         NaN         NaN
# 7         NaN         NaN         NaN         NaN         NaN         NaN
# 8         NaN         NaN         NaN         NaN         NaN         NaN
# 9         NaN         NaN         NaN         NaN         NaN         NaN
#
#    ...  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# 0  ...          NaN          NaN          NaN          NaN          NaN
# 1  ...          NaN          NaN          NaN          NaN          NaN
# 2  ...          NaN          NaN          NaN          NaN          NaN
# 3  ...          NaN          NaN          NaN          NaN          NaN
# 4  ...          NaN          NaN          NaN          NaN          NaN
# 5  ...          NaN          NaN          NaN          NaN          NaN
# 6  ...          NaN          NaN          NaN          NaN          NaN
# 7  ...          NaN          NaN          NaN          NaN          NaN
# 8  ...          NaN          NaN          NaN          NaN          NaN
# 9  ...          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN          NaN
# 6          NaN          NaN          NaN          NaN          NaN
# 7          NaN          NaN          NaN          NaN          NaN
# 8          NaN          NaN          NaN          NaN          NaN
# 9          NaN          NaN          NaN          NaN          NaN
#
# [10 rows x 26 columns]

# %% [markdown]
# ## Clean up data

# %% [markdown]
# ### df_curso_basico

# %%
# combine alternate translations into a single column
expanded_rows = []

for idx, row in df_curso_basico.iterrows():
    # add original row with spanish_sentence_1
    if pd.notna(row['spanish_sentence_1']):
        expanded_rows.append({
            'warao_sentence': row['warao_sentence'],
            'spanish_sentence': row['spanish_sentence_1']
        })
    
    # check for alternate translations in columns spanish_sentence_2-4
    for col in ['spanish_sentence_2', 'spanish_sentence_3', 'spanish_sentence_4']:
        if pd.notna(row[col]):
            expanded_rows.append({
                'warao_sentence': row['warao_sentence'],
                'spanish_sentence': row[col]
            })

# new dataframe
df_curso_basico_expanded = pd.DataFrame(expanded_rows)

print(f"Original number of examples: {len(df_curso_basico)}")
print(f"Expanded number of examples: {len(df_curso_basico_expanded)}")
display(df_curso_basico_expanded.head(20))
# Out:
# Original number of examples: 583
# Expanded number of examples: 838
#               warao_sentence             spanish_sentence
# 0           ¿Waraotuma sina?      ¿Quienes son los warao?
# 1               Ka ribu isía  Sobre nuestro idioma warao.
# 2      Ine buratana najoroya               Yo como cambur
# 3      Iji buratana najoroya              Tú comes cambur
# 4      Tai buratana najoroya             Ella come cambur
# 5      Tai buratana najoroya               Él come cambur
# 6      Oko Buratana najoroya      Nosotros comemos cambur
# 7      Oko Buratana najoroya      Nosotras comemos cambur
# 8     Yatu buratana najoroya         Ustedes comen cambur
# 9   Tatuma buratana najoroya           Ellos comen cambur
# 10  Tatuma buratana najoroya           ellas comen cambur
# 11       Ine karata teribuya                   Yo estudio
# 12     Ine Jomakaba najoroya              Yo como pescado
# 13     Iji buratana najoroya              Tú comes cambur
# 14       Iji Karata teribuya                  Tú estudias
# 15                Oko Jakaya            Nosotros corremos
# 16                Oko Jakaya            Nosotras corremos
# 17         Oko yakera nokoya     Nosotros escuchamos bien
# 18         Oko yakera nokoya     Nosotras escuchamos bien
# 19             Yatu jabataya             Ustedes escriben

# %% [markdown]
# ### df_warao_aribu

# %%
# if isupper == True, change warao_sentence to lowercase with the first letter capitalized
# Only apply transformation to rows where the string is fully uppercase
mask = df_warao_aribu_guide['warao_sentence'].str.isupper().fillna(False)
df_warao_aribu_guide.loc[mask, 'warao_sentence'] = df_warao_aribu_guide.loc[mask, 'warao_sentence'].str.lower().str.capitalize()

display(df_warao_aribu_guide[2:3])
display(df_warao_aribu_guide[83:94])
# Out:
#                                warao_sentence  \
# 2  Nobotomo delta amacuro arao kokotuka saba.
#
#                                     spanish_sentence
# 2  A los niños Warao de todas las Comunidades Ind...
#                     warao_sentence                          spanish_sentence
# 83                 Diana ine naria                                 ya me voy
# 84                 Diana oko naria                              ya nos vamos
# 85                    Diana ji omi                                ya, sin ti
# 86                  Diana yatu omi                           ya, sin ustedes
# 87                         Jaketae                              hasta mañana
# 88                     Naru, diana                                   vete ya
# 89                 Narukotu, diana                                váyanse ya
# 90               Diana naru ka omi                  Váyanse ya, sin nosotros
# 91                   Amaja ma bitu                            aquello es mío
# 92  Amate wajibaka jakotai ka bitu  aquella curiara que esta allá es nuestra
# 93           Tamaja karata ji bitu                    aquel cuaderno es tuyo

# %% [markdown]
# ### df_trab_warao_completo

# %%
# change all caps text to lowercase with the first letter capitalized
df_trab_warao_completo['warao_sentence'] = df_trab_warao_completo['warao_sentence'].str.lower().str.capitalize()

display(df_trab_warao_completo[100:108])
# Out:
#                          warao_sentence                      spanish_sentence  \
# 100  Nobotomo inaminanoko narukitane ja  Las niñas tienen que ir a la escuela
# 101        Inamina najoro nanakitane ja  Los maestros tienen que hacer comida
# 102                Jo era jobikitane ja           Hay que tomar bastante agua
# 103                  Yakera mikitane ja                      Hay que ver bien
# 104                       Sina iji tia?                           ¿Qué haces?
# 105                    Tana, ine dujuya                    Nada, sentado aquí
# 106                    Jaisa yabakitane                        Vamos a pescar
# 107          Iji usibakai ja yabakitane           Tienes anzuelos para pescar
#
#     Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 100        NaN         NaN         NaN         NaN         NaN         NaN
# 101        NaN         NaN         NaN         NaN         NaN         NaN
# 102        NaN         NaN         NaN         NaN         NaN         NaN
# 103        NaN         NaN         NaN         NaN         NaN         NaN
# 104        NaN         NaN         NaN         NaN         NaN         NaN
# 105        NaN         NaN         NaN         NaN         NaN         NaN
# 106        NaN         NaN         NaN         NaN         NaN         NaN
# 107        NaN         NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 100         NaN         NaN  ...          NaN          NaN          NaN
# 101         NaN         NaN  ...          NaN          NaN          NaN
# 102         NaN         NaN  ...          NaN          NaN          NaN
# 103         NaN         NaN  ...          NaN          NaN          NaN
# 104         NaN         NaN  ...          NaN          NaN          NaN
# 105         NaN         NaN  ...          NaN          NaN          NaN
# 106         NaN         NaN  ...          NaN          NaN          NaN
# 107         NaN         NaN  ...          NaN          NaN          NaN
#
#      Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 100          NaN          NaN          NaN          NaN          NaN
# 101          NaN          NaN          NaN          NaN          NaN
# 102          NaN          NaN          NaN          NaN          NaN
# 103          NaN          NaN          NaN          NaN          NaN
# 104          NaN          NaN          NaN          NaN          NaN
# 105          NaN          NaN          NaN          NaN          NaN
# 106          NaN          NaN          NaN          NaN          NaN
# 107          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 24  Unnamed: 25
# 100          NaN          NaN
# 101          NaN          NaN
# 102          NaN          NaN
# 103          NaN          NaN
# 104          NaN          NaN
# 105          NaN          NaN
# 106          NaN          NaN
# 107          NaN          NaN
#
# [8 rows x 26 columns]

# %%
df_all = pd.concat([df_curso_basico_expanded, df_ps_jw_website, df_warao_aribu_guide, df_trab_warao_completo])
# leave only spanish_sentence and warao_sentence columns
df_all = df_all[['spanish_sentence', 'warao_sentence']]
print(f"Total number of examples: {len(df_all)}")
# Out:
# Total number of examples: 1220

# %%
# extract rows that are exact duplicates
duplicates = df_all[df_all.duplicated(keep=False)]

duplicates_curso_basico = df_curso_basico_expanded[df_curso_basico_expanded.duplicated(keep=False)]
duplicates_warao_aribu = df_warao_aribu_guide[df_warao_aribu_guide.duplicated(keep=False)]
duplicates_ps_jw = df_ps_jw_website[df_ps_jw_website.duplicated(keep=False)]
duplicates_trab = df_trab_warao_completo[df_trab_warao_completo.duplicated(keep=False)]

print(f"Number of duplicate spanish sentences: {len(duplicates)}")
print(f"Number of duplicate spanish sentences in df_curso_basico_expanded: {len(duplicates_curso_basico)}")
print(f"Number of duplicate spanish sentences in df_warao_aribu_guide: {len(duplicates_warao_aribu)}")
print(f"Number of duplicate spanish sentences in df_ps_jw_website: {len(duplicates_ps_jw)}")
print(f"Number of duplicate spanish sentences in df_trab_warao_completo: {len(duplicates_trab)}")
display(duplicates.head(100))
# Out:
# Number of duplicate spanish sentences: 46
# Number of duplicate spanish sentences in df_curso_basico_expanded: 36
# Number of duplicate spanish sentences in df_warao_aribu_guide: 10
# Number of duplicate spanish sentences in df_ps_jw_website: 0
# Number of duplicate spanish sentences in df_trab_warao_completo: 0
#                      spanish_sentence               warao_sentence
# 3                     Tú comes cambur        Iji buratana najoroya
# 13                    Tú comes cambur        Iji buratana najoroya
# 321                      ella comerá.                 Tai najorote
# 322                        Él comerá.                 Tai najorote
# 323                  ella va a comer.                 Tai najorote
# 324                    Él va a comer.                 Tai najorote
# 353             Nosotros vamos a ver.                     Oko mite
# 354             Nosotros vamos a ver.                     Oko mite
# 468                    Yo estoy aquí.              Ine tamatika ja
# 469  Los niños trajeron al perro acá.  Nobotomo beoro tamate konae
# 470                   Juana está ahí.              Juana tatuka ja
# 472             Nosotros fuimos allá.              Oko tata naruae
# 474             Nosotras fuimos allá.              Oko tata naruae
# 475             El pescado está allá.              Jomakaba ote ja
# 476      El dinero se calló por aquí.      Burata tamajaisía nakae
# 477            El maestro es de aquí.         Inaminatu tamatikamo
# 478        Los niños salieron de ahí.   Nobotomo tatukamo ejobonae
# 479             Por allá hay pescado.         Jomakaba tataisía ja
# 480        Los perros vienen de allí.       Beorotuma tatamo naoya
# 502                      ella comerá.                 Tai najorote
# 503                        Él comerá.                 Tai najorote
# 504                  ella va a comer.                 Tai najorote
# 505                    Él va a comer.                 Tai najorote
# 516                    Yo estoy aquí.              Ine tamatika ja
# 517  Los niños trajeron al perro acá.  Nobotomo beoro tamate konae
# 518                   Juana está ahí.              Juana tatuka ja
# 520             Nosotros fuimos allá.              Oko tata naruae
# 522             Nosotras fuimos allá.              Oko tata naruae
# 523             El pescado está allá.              Jomakaba ote ja
# 524      El dinero se calló por aquí.      Burata tamajaisía nakae
# 525            El maestro es de aquí.         Inaminatu tamatikamo
# 527        Los niños salieron de ahí.   Nobotomo tatukamo ejobonae
# 528             Por allá hay pescado.         Jomakaba tataisía ja
# 529        Los perros vienen de allí.       Beorotuma tatamo naoya
# 642                         No hables                Dibunaka tanu
# 669                         No hables                Dibunaka tanu
# 49             Yo nací en esta ribera          Ine diawarae arauka
# 50                Del Arauca vibrador              A naba dubujeku
# 51           Soy hermano de la espuma          Ine jo a bana warao
# 52        De las garzas, de las rosas          Wara, tokoyo yatane
# 63             Yo nací en esta ribera          Ine diawarae arauka
# 64                Del Arauca vibrador              A naba dubujeku
# 65           Soy hermano de la espuma          Ine jo a bana warao
# 66        De las garzas, de las rosas          Wara, tokoyo yatane
# 151                    ¿Cómo sucedió?             ¿katukane tanae?
# 178                    ¿Cómo sucedió?             ¿katukane tanae?

# %%
df_all.drop_duplicates(inplace=True)
print(f"Total number of examples after dropping duplicates: {len(df_all)}")
# Out:
# Total number of examples after dropping duplicates: 1197
